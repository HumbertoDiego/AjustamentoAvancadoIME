# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HumbertoDiego/AjustamentoAvancadoIME/blob/main/08_estudo_de_caso_1.ipynb)

# %% [markdown]
# # Aula 8 — Estudo de Caso 1: Rede de Nivelamento com Injunções
#
# **Maj Diego - 1º Semestre / 2027**
#
# **Objetivos:**
#
# 1. Formular e ajustar uma rede altimétrica.
# 2. Comparar injunções fortes e estocásticas.
# 3. Quantificar precisão e confiabilidade.

# %% [markdown]
# ## Problema
#
# Uma rede de nivelamento com ao menos cinco pontos, dois controles e observações redundantes.

# %% [markdown]
# ## Etapas sugeridas
#
# 1. Definir hipótese, observações, parâmetros e unidades.
# 2. Fazer análise exploratória e controle de qualidade.
# 3. Implementar e validar o método.
# 4. Comparar alternativas ou cenários.
# 5. Comunicar conclusão, limitações e próximos passos.

# %% [markdown]
# ## Entregáveis
#
# Modelo matricial, coordenadas ajustadas, resíduos, covariâncias e análise do datum.

# %% [markdown]
# ## Critérios da 7ª VE oral
#
# - Correção da formulação e da implementação.
# - Rastreabilidade e reprodutibilidade.
# - Qualidade das verificações e da interpretação.
# - Clareza da apresentação e domínio na arguição.

# %%
# Espaço inicial para parâmetros, importações e dados do estudo de caso.
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

RNG = np.random.default_rng(2027)
