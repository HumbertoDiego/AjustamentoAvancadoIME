# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HumbertoDiego/AjustamentoAvancadoIME/blob/main/10_estudo_de_caso_3.ipynb)

# %% [markdown]
# # Aula 10 — Estudo de Caso 3: Série Temporal de Monitoramento
#
# **Maj Diego - 1º Semestre / 2027**
#
# **Objetivos:**
#
# 1. Estimar tendência e sazonalidade.
# 2. Detectar descontinuidades ou valores anômalos.
# 3. Interpretar taxas e incertezas.

# %% [markdown]
# ## Problema
#
# Série temporal GNSS, de recalque ou de deslocamento estrutural.

# %% [markdown]
# ## Etapas sugeridas
#
# 1. Definir hipótese, observações, parâmetros e unidades.
# 2. Fazer análise exploratória e controle de qualidade.
# 3. Implementar e validar o método.
# 4. Comparar alternativas ou cenários.
# 5. Comunicar conclusão, limitações e próximos passos.

# %% [markdown]
# ## Entregáveis
#
# Modelo temporal, diagnóstico dos resíduos, visualização e interpretação física.

# %% [markdown]
# ## Critérios da 7ª VE oral
#
# - Correção da formulação e da implementação.
# - Rastreabilidade e reprodutibilidade.
# - Qualidade das verificações e da interpretação.
# - Clareza da apresentação e domínio na arguição.

# %%
# Espaço inicial para parâmetros, importações e dados do estudo de caso.
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

RNG = np.random.default_rng(2027)
