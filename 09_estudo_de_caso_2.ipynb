# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HumbertoDiego/AjustamentoAvancadoIME/blob/main/09_estudo_de_caso_2.ipynb)

# %% [markdown]
# # Aula 9 — Estudo de Caso 2: Controle de Qualidade e Outliers em Rede
#
# **Maj Diego - 1º Semestre / 2027**
#
# **Objetivos:**
#
# 1. Aplicar teste global e data snooping.
# 2. Comparar L2 e ajuste robusto.
# 3. Justificar a decisão sobre observações suspeitas.

# %% [markdown]
# ## Problema
#
# Uma rede ou regressão geodésica contendo erros aleatórios e ao menos um outlier controlado.

# %% [markdown]
# ## Etapas sugeridas
#
# 1. Definir hipótese, observações, parâmetros e unidades.
# 2. Fazer análise exploratória e controle de qualidade.
# 3. Implementar e validar o método.
# 4. Comparar alternativas ou cenários.
# 5. Comunicar conclusão, limitações e próximos passos.

# %% [markdown]
# ## Entregáveis
#
# Tabela de testes, gráficos de resíduos, soluções comparadas e decisão técnica.

# %% [markdown]
# ## Critérios da 7ª VE oral
#
# - Correção da formulação e da implementação.
# - Rastreabilidade e reprodutibilidade.
# - Qualidade das verificações e da interpretação.
# - Clareza da apresentação e domínio na arguição.

# %%
# Espaço inicial para parâmetros, importações e dados do estudo de caso.
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

RNG = np.random.default_rng(2027)
