# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HumbertoDiego/AjustamentoAvancadoIME/blob/main/12_estudo_de_caso_5.ipynb)

# %% [markdown]
# # Aula 12 — Estudo de Caso 5: Projeto Integrador e Defesa Oral
#
# **Maj Diego - 1º Semestre / 2027**
#
# **Objetivos:**
#
# 1. Integrar modelagem, controle de qualidade e otimização.
# 2. Produzir uma solução reproduzível.
# 3. Defender escolhas e limitações na 7ª VE oral.

# %% [markdown]
# ## Problema
#
# Problema de Engenharia Cartográfica escolhido pela equipe e aprovado pelo docente.

# %% [markdown]
# ## Etapas sugeridas
#
# 1. Definir hipótese, observações, parâmetros e unidades.
# 2. Fazer análise exploratória e controle de qualidade.
# 3. Implementar e validar o método.
# 4. Comparar alternativas ou cenários.
# 5. Comunicar conclusão, limitações e próximos passos.

# %% [markdown]
# ## Entregáveis
#
# Notebook final, apresentação curta, dados e referências, resultados validados e defesa oral.

# %% [markdown]
# ## Critérios da 7ª VE oral
#
# - Correção da formulação e da implementação.
# - Rastreabilidade e reprodutibilidade.
# - Qualidade das verificações e da interpretação.
# - Clareza da apresentação e domínio na arguição.

# %%
# Espaço inicial para parâmetros, importações e dados do estudo de caso.
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

RNG = np.random.default_rng(2027)
